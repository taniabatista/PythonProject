# %%
import os
#from tqdm import tqdm
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.tools.plotting import radviz

#---------------- IMPORT MODULES --------------------
import csv
import requests
import openpyxl
from openpyxl import Workbook
print (openpyxl.__version__)
# Out:
# 2.4.8

# %%
#download these TWO files:

#www.kaggle.com/camnugent/sandp500/downloads/all_stocks_5yr.csv
      #https://raw.githubusercontent.com/taniabatista/PythonProject/master/all_stocks_5yr_shortened.csv

#https://github.com/datasets/s-and-p-500-companies/blob/master/data/constituents-financials.csv
      #https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents-financials.csv

# %%
constituents_URL = 'https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents-financials.csv'

xl_file = openpyxl.Workbook()
xl_tab = xl_file.create_sheet(index=0, title='Content')

with requests.Session() as session_object:
    download = session_object.get(constituents_URL)
    decoded_content = download.content.decode('utf-8')
    url_object = csv.reader(decoded_content.splitlines(), delimiter=',')
    print ("File: ", url_object, "\n\n")
    print ("========= Importing the following CSV content from the URL =========== ", "\n\n")
    print ("HEADER INDEX ------------------- ( ROW, COLUMN )", "\n\n")    
    rw=0
    for obj in url_object:
    	rw+=1
    	kl=1
    	for print_row in obj:
    		print (print_row,' ------------------- ','(',rw,',',kl,')')
    		xl_tab.cell(row=rw, column=kl).value = print_row
    		kl+=1
xl_file.save('constituents-financials_new.csv')
print ("CSV from URL Download Complete")
# Out:
# File:  <_csv.reader object at 0x0000028EE5501800>
#
#
# ========= Importing the following CSV content from the URL ===========
#
#
# HEADER INDEX ------------------- ( ROW, COLUMN )
#
#
# Symbol  -------------------  ( 1 , 1 )
# Name  -------------------  ( 1 , 2 )
# Sector  -------------------  ( 1 , 3 )
# Price  -------------------  ( 1 , 4 )
# Dividend Yield  -------------------  ( 1 , 5 )
# Price/Earnings  -------------------  ( 1 , 6 )
# Earnings/Share  -------------------  ( 1 , 7 )
# Book Value  -------------------  ( 1 , 8 )
# 52 week low  -------------------  ( 1 , 9 )
# 52 week high  -------------------  ( 1 , 10 )
# Market Cap  -------------------  ( 1 , 11 )
# EBITDA  -------------------  ( 1 , 12 )
# Price/Sales  -------------------  ( 1 , 13 )
# Price/Book  -------------------  ( 1 , 14 )
# SEC Filings  -------------------  ( 1 , 15 )
# MMM  -------------------  ( 2 , 1 )
# 3M Company  -------------------  ( 2 , 2 )
# Industrials  -------------------  ( 2 , 3 )
# ...

# %%
#------------------------- READ THE PATH INTO THE NOTEBOOK ------------------------
pwd = os.getcwd()
path_constituents_fin = pwd+'\\'+'constituents-financials_new.csv'
read_path_cons_file= pd.ExcelFile(path_constituents_fin) #, encoding='utf-8')
external_constituents_dataframe = read_path_cons_file.parse('Content')

# %%
#----------------- TEST IT ---------------
external_constituents_dataframe
# Out:
#     Symbol                           Name                  Sector   Price  \
# 0      MMM                     3M Company             Industrials  189.09
# 1      ABT            Abbott Laboratories             Health Care   45.00
# 2     ABBV                         AbbVie             Health Care   63.69
# 3      ACN                  Accenture plc  Information Technology  124.14
# 4     ATVI            Activision Blizzard  Information Technology   48.06
# 5      AYI              Acuity Brands Inc             Industrials  205.41
# 6     ADBE              Adobe Systems Inc  Information Technology  119.98
# 7      AAP             Advance Auto Parts  Consumer Discretionary  151.99
# 8      AES                       AES Corp               Utilities   11.33
# 9      AET                      Aetna Inc             Health Care  130.59
# 10     AMG  Affiliated Managers Group Inc              Financials  166.56
# 11     AFL                      AFLAC Inc              Financials   71.95
# ...

# %%
# ----------- Print only the Sector column ----------- 
print ("Sector Column: ")
print (external_constituents_dataframe.Sector.head())
print ("\n\n")
# ----------- Print only the Name column -----------
print ("Stock's Name Column: ")
print (external_constituents_dataframe.Name.head())
print ("\n\n")
# Out:
# Sector Column:
# 0               Industrials
# 1               Health Care
# 2               Health Care
# 3    Information Technology
# 4    Information Technology
# Name: Sector, dtype: object
#
#
#
# Stock's Name Column:
# 0             3M Company
# 1    Abbott Laboratories
# 2                 AbbVie
# 3          Accenture plc
# 4    Activision Blizzard
# Name: Name, dtype: object
